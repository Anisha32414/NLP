# %%
"""
NN: Noun, singular or mass (e.g., dog, book)
NNS: Noun, plural (e.g., dogs, books)
NNP: Proper noun, singular (e.g., India, Delhi)
NNPS: Proper noun, plural (e.g., Indians)
VB: Verb, base form (e.g., eat, run)
VBD: Verb, past tense (e.g., ate, ran)
VBG: Verb, gerund or present participle (e.g., eating, running)
VBN: Verb, past participle (e.g., eaten, run)
VBP: Verb, non-3rd person singular present (e.g., eat, run)
VBZ: Verb, 3rd person singular present (e.g., eats, runs)
JJ: Adjective (e.g., big, happy)
JJR: Adjective, comparative (e.g., bigger)
JJS: Adjective, superlative (e.g., biggest)
RB: Adverb (e.g., quickly, very)
RBR: Adverb, comparative (e.g., quicker)
RBS: Adverb, superlative (e.g., quickest)
PRP: Personal pronoun (e.g., I, he, they)
PRP$: Possessive pronoun (e.g., my, his, their)
DT: Determiner (e.g., the, a, this)
IN: Preposition or subordinating conjunction (e.g., in, of, that)
CC: Coordinating conjunction (e.g., and, but, or)
CD: Cardinal number (e.g., one, 5, 1991)
EX: Existential there (e.g., there is a dog)
FW: Foreign wordMD: Modal (e.g., can, should)
UH: Interjection (e.g., oh, wow)
"""
# Out:
# '\nNN: Noun, singular or mass (e.g., dog, book)\nNNS: Noun, plural (e.g., dogs, books)\nNNP: Proper noun, singular (e.g., India, Delhi)\nNNPS: Proper noun, plural (e.g., Indians)\nVB: Verb, base form (e.g., eat, run)\nVBD: Verb, past tense (e.g., ate, ran)\nVBG: Verb, gerund or present participle (e.g., eating, running)\nVBN: Verb, past participle (e.g., eaten, run)\nVBP: Verb, non-3rd person singular present (e.g., eat, run)\nVBZ: Verb, 3rd person singular present (e.g., eats, runs)\nJJ: Adjective (e.g., big, happy)\nJJR: Adjective, comparative (e.g., bigger)\nJJS: Adjective, superlative (e.g., biggest)\nRB: Adverb (e.g., quickly, very)\nRBR: Adverb, comparative (e.g., quicker)\nRBS: Adverb, superlative (e.g., quickest)\nPRP: Personal pronoun (e.g., I, he, they)\nPRP$: Possessive pronoun (e.g., my, his, their)\nDT: Determiner (e.g., the, a, this)\nIN: Preposition or subordinating conjunction (e.g., in, of, that)\nCC: Coordinating conjunction (e.g., and, but, or)\nCD: Cardinal number
# ...

# %%
paragraph="Today, I stand before you to talk about a force that is quietly but " \
"radically reshaping our world: Artificial Intelligence. " \
"Once relegated to the realm of science fiction, AI is now the invisible engine driving our daily " \
"lives. From the moment we wake up and check our phones with facial recognition, to the routes " \
"we take using maps, and the entertainment we stream, AI is constantly analyzing data, learning " \
"patterns, and making decisions to make our lives easier and more efficient. " \
"Beyond our personal conveniences, AI is tackling some of humanity's biggest challenges. " \
"In healthcare, machine learning algorithms are helping doctors detect diseases like cancer at " \
"much earlier stages. In education, AI is personalizing learning experiences—adapting to a " \
"student's unique pace and needs. It is also transforming industries from agriculture to finance, " \
"making processes smarter and more sustainable."

# %%
from nltk.corpus import stopwords
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['Today, I stand before you to talk about a force that is quietly but radically reshaping our world: Artificial Intelligence.',
#  'Once relegated to the realm of science fiction, AI is now the invisible engine driving our daily lives.',
#  'From the moment we wake up and check our phones with facial recognition, to the routes we take using maps, and the entertainment we stream, AI is constantly analyzing data, learning patterns, and making decisions to make our lives easier and more efficient.',
#  "Beyond our personal conveniences, AI is tackling some of humanity's biggest challenges.",
#  'In healthcare, machine learning algorithms are helping doctors detect diseases like cancer at much earlier stages.',
#  "In education, AI is personalizing learning experiences—adapting to a student's unique pace and needs.",
#  'It is also transforming industries from agriculture to finance, making processes smarter and more sustainable.']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\anish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
## Apply Stopwords and filter and the apply stemming

for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    filtered_words=[word for word in words if word not in set(stopwords.words('english'))]
    pos_tag=nltk.pos_tag(filtered_words)
    print(pos_tag)
# Out:
# [('Today', 'NN'), (',', ','), ('I', 'PRP'), ('stand', 'VBP'), ('talk', 'VB'), ('force', 'NN'), ('quietly', 'RB'), ('radically', 'RB'), ('reshaping', 'VBG'), ('world', 'NN'), (':', ':'), ('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('.', '.')]
# [('Once', 'RB'), ('relegated', 'VBN'), ('realm', 'NN'), ('science', 'NN'), ('fiction', 'NN'), (',', ','), ('AI', 'NNP'), ('invisible', 'JJ'), ('engine', 'NN'), ('driving', 'VBG'), ('daily', 'JJ'), ('lives', 'NNS'), ('.', '.')]
# ...

# %%
"Taj Mahal is a beautiful Monument".split()
# Out:
# ['Taj', 'Mahal', 'is', 'a', 'beautiful', 'Monument']

# %%
print(nltk.pos_tag("Taj Mahal is a beautiful Monument".split()))
# Out:
# [('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('Monument', 'NN')]
